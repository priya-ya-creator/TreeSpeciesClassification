# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Tree_classification_dataset.zip"
# Out:
# /content/drive/MyDrive/Tree_classification_dataset.zip

# %%
from zipfile import ZipFile
import os

zip_path = '/content/drive/MyDrive/Tree_classification_dataset.zip'
extract_path = '/content/Tree_Species_Dataset'

if not os.path.isfile(zip_path):
    print(f"❌ Error: File '{zip_path}' not found.")
else:
    try:
        with ZipFile(zip_path, 'r') as zipObj:
            zipObj.extractall(extract_path)
        print("✅ Extraction completed! Dataset is in:", extract_path)
    except Exception as e:
        print(f"❌ An error occurred during extraction: {e}")
# Out:
# ✅ Extraction completed! Dataset is in: /content/Tree_Species_Dataset

# %%
# !ls /content/tree_dataset/Tree_Species_Dataset
# Out:
# amla	  bili	   gulmohor  khajur	  other       simlo
# asopalav  cactus   gunda     mango	  pilikaren   sitafal
# babul	  champa   jamun     motichanoti  pipal       sonmahor
# bamboo	  coconut  kanchan   neem	  saptaparni  sugarcane
# banyan	  garmalo  kesudo    nilgiri	  shirish     vad

# %%
# !zip -r Tree_classification_dataset.zip "/content/Tree_Species_Dataset"
# Out:
#   adding: content/Tree_Species_Dataset/ (stored 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/ (stored 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/ (stored 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image9.jpg (deflated 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image37.jpg (deflated 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image10.jpg (deflated 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image11.jpg (deflated 1%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image44.jpg (deflated 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image14.jpg (deflated 1%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image5.jpg (deflated 0%)
#   adding: content/Tree_Species_Dataset/Tree_Species_Dataset/garmalo/image24.jpg (deflated 1%)
# ...
